# %%
from flyquery import get_genotype, fill_info
import pandas as pd

# %%
file = '~/Downloads/stocks_DG_July2020_QR1.csv'
df = pd.read_csv(file)
df
# Out:
#     BDSC#  Name    Status  Row  Tray             Room
# 0   30839   NaN   Healthy    1     1  Quarantine Room
# 1   38757   NaN   Healthy    1     1  Quarantine Room
# 2   39521   NaN   Healthy    1     1  Quarantine Room
# 3   39906   NaN   Healthy    1     1  Quarantine Room
# 4   40679   NaN   Healthy    1     1  Quarantine Room
# 5   48510   NaN   Healthy    1     1  Quarantine Room
# 6   48550   NaN   Healthy    1     1  Quarantine Room
# 7   49032   NaN   Healthy    1     1  Quarantine Room
# 8   49298   NaN   Healthy    1     1  Quarantine Room
# 9   49646   NaN   Healthy    1     1  Quarantine Room
# 10  53488   NaN   Healthy    5     1  Quarantine Room
# 11  54086   NaN  Critical    5     1  Quarantine Room
# 12  54339   NaN   Healthy    5     1  Quarantine Room
# 13  61600   NaN   Healthy    5     1  Quarantine Room
# 14  63739   NaN   Healthy    5     1  Quarantine Room
# 15  69079   NaN   Healthy    5     1  Quarantine Room
# ...

# %%
df = fill_info(df, stock_id='BDSC#', to_col='Name')
df
# Out:
#     BDSC#                                               Name    Status  Row  \
# 0   30839                    w[*]; P{w[+mW.hs]=GawB}cv-c[C5]   Healthy    1
# 1   38757     w[1118]; P{y[+t7.7] w[+mC]=GMR50F12-GAL4}attP2   Healthy    1
# 2   39521     w[1118]; P{y[+t7.7] w[+mC]=GMR70C02-GAL4}attP2   Healthy    1
# 3   39906     w[1118]; P{y[+t7.7] w[+mC]=GMR75G12-GAL4}attP2   Healthy    1
# 4   40679     w[1118]; P{y[+t7.7] w[+mC]=GMR94C05-GAL4}attP2   Healthy    1
# 5   48510     w[1118]; P{y[+t7.7] w[+mC]=GMR12E09-GAL4}attP2   Healthy    1
# 6   48550     w[1118]; P{y[+t7.7] w[+mC]=GMR13C03-GAL4}attP2   Healthy    1
# 7   49032     w[1118]; P{y[+t7.7] w[+mC]=GMR23E10-GAL4}attP2   Healthy    1
# 8   49298     w[1118]; P{y[+t7.7] w[+mC]=GMR22A12-GAL4}attP2   Healthy    1
# 9   49646     w[1118]; P{y[+t7.7] w[+mC]=GMR30G03-GAL4}attP2   Healthy    1
# 10  53488    w[1118]; P{y[+t7.7] w[+mC]=GMR49C04-lexA}attP40   Healthy    5
# ...

# %%
df.to_csv('~/Downloads/stocks_DG_July2020_QR1.csv', index=False)
